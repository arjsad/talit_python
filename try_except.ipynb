# %%
import random
 
number = random.randint(1, 100)
attempts = 0
guess = None
 
while True:
    try:
        guess = int(input("Errate eine Zahl von 1-100"))
        if guess == number:
            print(f"Richtig, die Zahl ist: {number}")
            break
        elif guess < number:
            print("Die Zahl ist höher")
        elif guess > number:
            print("Die Zahl ist tiefer")
    except ValueError:
        print("Der Input kann nicht in Zahlen umgewandelt werden! Versuche es nochmals.")

    else:
        attempts += 1
    if attempts == 10:
        print(f"Leider nein. die Zahl war {secret}")
# Out:
# Die Zahl ist tiefer
# Die Zahl ist höher
# Die Zahl ist höher
# Die Zahl ist tiefer
# Die Zahl ist tiefer
# Die Zahl ist tiefer
# Die Zahl ist tiefer
# Die Zahl ist tiefer
# Richtig, die Zahl ist: 61
